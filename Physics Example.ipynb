# %% [markdown]
# ## 3<sup>rd</sup> Year Project Lab Book

# %% [markdown]
# ### This is an example notebook for physics 3rd year students

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x=np.linspace(0,200,100)
y=x**2
plt.plot(x,y,'ro')
